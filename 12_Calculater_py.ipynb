# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitasharmamca2025-jpg/Python_Assesment.py/blob/main/12_Calculater_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#12.Exception Handling Calculator:
def calculator():
    print("Simple Calculator")

    while True:
        # --- Input for first number ---
        try:
            num1 = float(input("Enter the first number (or 'q' to quit): "))
        except ValueError:
            # Handle case where initial input is not a number
            user_input = input("Enter the first number (or 'q' to quit): ")
            if user_input.lower() == 'q':
                print("Exiting calculator. Goodbye!")
                break
            try:
                num1 = float(user_input)
            except ValueError:
                print("Invalid input for the first number. Please enter a numeric value.")
                continue # Restart loop for valid input

        # --- Input for second number ---
        try:
            num2 = float(input("Enter the second number: "))
        except ValueError:
            print("Invalid input for the second number. Please enter a numeric value.")
            continue # Restart loop for valid input

        # --- Input for operation ---
        operation = input("Enter an operation (+, -, *, /): ")

        # --- Perform calculation and handle errors ---
        try:
            result = None
            if operation == '+':
                result = num1 + num2
            elif operation == '-':
                result = num1 - num2
            elif operation == '*':
                result = num1 * num2
            elif operation == '/':
                if num2 == 0:
                    raise ZeroDivisionError("Cannot divide by zero!")
                result = num1 / num2
            else:
                raise ValueError("Invalid operation. Please use +, -, *, or /.")

            print(f"Result: {num1} {operation} {num2} = {result}")

        except ZeroDivisionError as e:
            print(f"Error: {e}")
        except ValueError as e:
            print(f"Error: {e}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

        print("\n") # Add a newline for better readability between calculations

calculator()
# Out:
# Simple Calculator
# Enter the first number (or 'q' to quit): 3
# Enter the second number: 5
# Enter an operation (+, -, *, /): +
# Result: 3.0 + 5.0 = 8.0
#
#
# Enter the first number (or 'q' to quit): q
# Enter the first number (or 'q' to quit): q
# Exiting calculator. Goodbye!
