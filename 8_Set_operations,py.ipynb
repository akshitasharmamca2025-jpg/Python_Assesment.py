# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitasharmamca2025-jpg/Python_Assesment.py/blob/main/8_Set_operations%2Cpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# Q8 Set Operations
# =========================

# Creating sets
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# Perform union operation
print("Union:", set1 | set2)

# Perform intersection operation
print("Intersection:", set1 & set2)

# Perform symmetric difference
print("Symmetric Difference:", set1 ^ set2)

# Check subset
if set1.issubset(set2):
    print("Set1 is subset of Set2")

else:
    print("Set1 is not subset of Set2")
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Symmetric Difference: {1, 2, 5, 6}
# Set1 is not subset of Set2
