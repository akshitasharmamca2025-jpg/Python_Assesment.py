# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitasharmamca2025-jpg/Python_Assesment.py/blob/main/5_Largest__or_smallest_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# Q5 Second Largest & Smallest
# =========================

# List of numbers
nums = [10, 5, 8, 20, 2]

# Initialize variables
largest = second_largest = -99999
smallest = second_smallest = 99999

# Loop through list
for n in nums:

    # Find largest and second largest
    if n > largest:
        second_largest = largest
        largest = n

    elif n > second_largest and n != largest:
        second_largest = n

    # Find smallest and second smallest
    if n < smallest:
        second_smallest = smallest
        smallest = n

    elif n < second_smallest and n != smallest:
        second_smallest = n

# Display result
print("Second Largest:", second_largest)
print("Second Smallest:", second_smallest)
# Out:
# Second Largest: 10
# Second Smallest: 5
